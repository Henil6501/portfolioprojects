# %% [markdown]
# <a href="https://colab.research.google.com/github/Henil6501/portfolioprojects/blob/main/A1_assessment_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/bank dataset.csv.csv")

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0     60.0    management   married    primary      no  21292.0      no   no
# 3     43.0    management   married   tertiary      no      0.0      no   no
# 4     35.0    management    single   tertiary      no   2576.0     yes  yes
# 5     37.0    management   married   tertiary      no     40.0      no   no
# 6     45.0    technician   married  secondary      no   2403.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 6777  34.0  entrepreneur   married   tertiary      no    368.0      no  yes
# 6778  51.0     housemaid  divorced   tertiary      no   1613.0      no   no
# 6779  34.0   blue-collar   married    primary      no    654.0      no   no
# 6780  33.0    management    single   tertiary      no   1150.0     yes   no
# 6781  37.0        admin.   married  secondary      no   3226.0     yes  yes
#
# ...

# %%
df.dtypes
# Out:
# age          float64
# job           object
# marital       object
# education     object
# default       object
# balance      float64
# housing       object
# loan          object
# contact       object
# day          float64
# month         object
# duration     float64
# campaign     float64
# pdays        float64
# previous       int64
# poutcome      object
# y             object
# dtype: object

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  6779.000000   6775.000000  6780.000000  6779.000000  6772.000000
# mean     41.008261   1383.483100    15.809882   257.947780     2.695659
# std      10.558466   2922.468474     8.266936   260.823676     2.923879
# min      18.000000  -3058.000000     1.000000     3.000000     1.000000
# 25%      33.000000     73.500000     8.000000   105.000000     1.000000
# 50%      39.000000    465.000000    16.000000   180.000000     2.000000
# 75%      48.000000   1482.500000    21.000000   317.000000     3.000000
# max      92.000000  56831.000000    31.000000  3284.000000    55.000000
#
#              pdays     previous
# count  6774.000000  6782.000000
# mean     38.993209     0.590239
# std      97.851380     1.920952
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     791.000000    38.000000

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# age           3
# job           3
# marital       2
# education     4
# default       3
# balance       7
# housing       4
# loan          7
# contact       1
# day           2
# month         5
# duration      3
# campaign     10
# pdays         8
# previous      0
# poutcome      1
# y             0
# dtype: int64

# %%
df = df.dropna()

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
duplicate= df.duplicated().any()
print(duplicate)
# Out:
# False

# %%
pd.get_dummies(df, columns=['month'])
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0     60.0    management   married    primary      no  21292.0      no   no
# 3     43.0    management   married   tertiary      no      0.0      no   no
# 4     35.0    management    single   tertiary      no   2576.0     yes  yes
# 5     37.0    management   married   tertiary      no     40.0      no   no
# 6     45.0    technician   married  secondary      no   2403.0      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 6777  34.0  entrepreneur   married   tertiary      no    368.0      no  yes
# 6778  51.0     housemaid  divorced   tertiary      no   1613.0      no   no
# 6779  34.0   blue-collar   married    primary      no    654.0      no   no
# 6780  33.0    management    single   tertiary      no   1150.0     yes   no
# 6781  37.0        admin.   married  secondary      no   3226.0     yes  yes
#
# ...
